# %%
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
import matplotlib.pyplot as plt

# %%
from mpl_toolkits.basemap import Basemap

# %%
gStatsCP = pd.read_pickle("data/gStatsCP.pkl")
gStatsCP
# Out:
#                                                geometry  \
# 0     POLYGON ((4.91095 45.23337, 4.89021 45.21371, ...
# 1     POLYGON ((5.42979 44.70325, 5.41301 44.68804, ...
# 2     POLYGON ((5.04539 44.55971, 5.03441 44.53369, ...
# 3     POLYGON ((5.19335 44.93648, 5.18288 44.91814, ...
# 4     POLYGON ((5.49711 44.25204, 5.47321 44.25469, ...
# ...                                                 ...
# 6262  POLYGON ((6.16080 47.28812, 6.16238 47.29451, ...
# 6263  POLYGON ((5.35736 44.31648, 5.33570 44.31047, ...
# 6264  POLYGON ((5.15645 44.88259, 5.15297 44.87448, ...
# 6265  POLYGON ((4.84420 44.34253, 4.84015 44.34079, ...
# 6266  POLYGON ((2.54757 48.67178, 2.53362 48.65734, ...
#
#                       _nomVille  _CodePoste  Reelected  total       pct
# 0         Saint-Rambert-d'Albon       26140        2.0    4.0  0.500000
# 1                           Die       26150        2.0   14.0  0.142857
# 2          La  Bégude-de-Mazenc       26160        6.0   14.0  0.428571
# ...

# %%
fig, ax = plt.subplots(1, figsize=(20, 20))#,cmap='Blues'
variable = 'pct'
gStatsCP.plot(column=variable, scheme='QUANTILES', linewidth=0.8,  ax=ax, edgecolor='0.8', legend=True)
ax.axis('off')
#fig.suptitle('Reelected mayors %')

# %%
fig.savefig('map_export.png', dpi=300)
